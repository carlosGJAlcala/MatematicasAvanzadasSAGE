# %%
#ejercicio1 

fx=[1.6449340,1.2020569,1.0823232]
y=[2,3,4]
fxd=[-1,4,2]



for i in range(1,len(y)):
    n=fx[i]-fx[i-1]
    d=y[i]-y[i-1]
    r=n/d
    print(r)   



###### 1a

fx1=-0.442877100000000
fx2=0.119733700000000
n=fx2-fx1
d=y[2]-y[0]
r=n/d
print(r)
# Out:
# -0.442877100000000
# -0.119733700000000
# 0.281305400000000

# %%
#1b
y=[2,2,3,3,4,4]
fx2=-0.442877100000000
fx1=-1
n=fx2-fx1
d=y[2]-y[0]
r=n/d
print(r)
# Out:
# 0.557122900000000

# %%
fx1=-0.442877100000000
fx2=-4
n=fx2-fx1
d=y[2]-y[0]
r=n/d
print(r)
# Out:
# -3.55712290000000

# %%
fx1=-0.119733700000000
fx2=2
n=fx2-fx1
d=y[4]-y[2]
r=n/d
print(r)
# Out:
# 2.11973370000000

# %%
fx1=0.557122900000000
fx2=-3.55712290000000
n=fx2-fx1
d=y[2]-y[0]
r=n/d
print(r)
# Out:
# -4.11424580000000

# %%
fx2=2.11973370000000
fx1=-3.55712290000000
n=fx2-fx1
d=y[4]-y[2]
r=n/d
print(r)
# Out:
# 5.67685660000000

# %%
fx1=-4.11424580000000
fx1=5.67685660000000
n=fx2-fx1
d=y[4]-y[0]
r=n/d
print(r)
# Out:
# -1.77856145000000

# %%
plot([(1.6449340,2),1.2020569,1.0823232])
#1c
hermite=1.6449340+x+557122900000000*x^2-4.11424580000000*x^3-1.77856145000000*x^4
neutown=1.6449340-0.442877100000000*x+0.281305400000000*x^2

# %%
hermit=plot(1.6449340+x+557122900000000*x^2-4.11424580000000*x^3-1.77856145000000*x^4)
hermit
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
Ne=plot(1.6449340-0.442877100000000*x+0.281305400000000*x^2)
Ne
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
hermit+Ne
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Ejercicio 2

# %%
m=Matrix([[1,1,1,1,1,1],[0,1,2,3,4,5],[0,0,2,6,12,20]])

# %%
v=vector([2,1,1])

# %%
m.solve_right(v)
# Out:
# (3/2, 0, 1/2, 0, 0, 0)

# %%
m=Matrix([[1,1,1,1,1],[0,1,2,3,4],[0,0,2,6,12],[1,4,16,32,64],[1,5,25,125,625],[0,1,10,75,500]])

# %%
v=vector([-2,3,1,0,1,-1])

# %%
m.solve_right(v)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-b5971dc01a07> in <module>
# ----> 1 m.solve_right(v)
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2.Matrix.solve_right (build/cythonized/sage/matrix/matrix2.c:8446)()
#     845
#     846         if not self.is_square():
# --> 847             X = self._solve_right_general(C, check=check)
#     848         else:
#     849             try:
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2.Matrix._solve_right_general (build/cythonized/sage/matrix/matrix2.c:9786)()
#     968             # Have to check that we actually solved the equation.
#     969             if self*X != B:
# --> 970                 raise ValueError("matrix equation has no solutions")
#     971         return X
#     972
#
# ...

# %%
fx=[1,-1,1,-1]
y=[1,2,3,5]
fxd=[-1,4,2]



for i in range(1,len(y)):
    n=fx[i]-fx[i-1]
    d=y[i]-y[i-1]
    r=n/d
    print(r)   



###### 1a
# Out:
# -2
# 2
# -1

# %%
fx1=-1
fx1=-2/9
n=fx2-fx1
d=y[3]-y[0]
r=n/d
print(r)
# Out:
# 11/36

# %%
#Ejercicio 1 sage
region_plot?
var('y')
parabola=(y^2)<x+1
circulo=(x+2)^2+(y-2)^2>2

# %%
 region_plot(circulo, (x,-6,6), (y,-6,6))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
 region_plot(parabola, (x,-6,6), (y,-6,6))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#ejercio 2 sage
var('z')
a=(x^2+y^2)/(x-y)
b=log((x+y)/(x-y))

# %%
implicit_plot3d(a ,(x,-3,3), (y,-3,3), (z,-3,3), adaptive=True)
# Out:
# Graphics3d Object

# %%
implicit_plot3d(b ,(x,-3,3), (y,-3,3), (z,-3,3))
# Out:
# Graphics3d Object
